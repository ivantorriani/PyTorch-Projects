# %%
#imports - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

import numpy as np
import torch
import os 
torch.set_printoptions(edgeitems=2, threshold=50)
import imageio

# Importing and formatting images - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

img_numpy = imageio.imread(r'C:\Users\sotiv\data\p1ch4\image-dog\bobby.jpg')

img_numpy.shape #Images come to us in NumPy, and incorrect formatting!

img_torch = torch.from_numpy(img_numpy) #Changing to Torch lets us perform operations

img_torch.shape 

correct_image = img_torch.permute(2, 0, 1) #Correctly formats 

correct_image.shape

# Loading Images in Large Amounts- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

batch_size = 3 #How many images are you getting?

batch = torch.zeros(batch_size, 3, 256, 256, dtype = torch.uint8) #This batch is going to hold all your information...

data_site = (r'C:\Users\sotiv\data\p1ch4\image-cats') #Location of folder with all the images

filesnames = [name for name in os.listdir(data_site)
              if os.path.splitext(name)[-1] == '.png']

for i, filename in enumerate(filesnames): #Get the data and put it in the batch!
    img_arr = imageio.imread(os.path.join(data_site, filename))
    img_t = torch.from_numpy(img_arr)
    img_t = img_t.permute(2, 0, 1)
    img_t = img_t[:3]
    batch[i] = img_t

batch = batch.float() # Normalize the data 
batch /= 255.0

n_channels = batch.shape[1]


for c in range(n_channels): #Another way to normalize the data
    mean = torch.mean(batch[:, c])
    std = torch.std(batch[:, c])
    batch [:, c] = (batch[:, c] - mean) / std

         

# 3D Images - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - 

# N X C X D X H X W: Want to have N batches, with C channel, of D depth, with H height, and W width !?!?!
# Out:
# C:\Users\sotiv\AppData\Local\Temp\ipykernel_18088\366382663.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_numpy = imageio.imread(r'C:\Users\sotiv\data\p1ch4\image-dog\bobby.jpg')
# C:\Users\sotiv\AppData\Local\Temp\ipykernel_18088\366382663.py:35: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img_arr = imageio.imread(os.path.join(data_site, filename))
# tensor([[[[ 0.1439,  0.0730,  ...,  0.0198,  0.1794],
#           [ 0.4631, -0.2461,  ..., -0.2107, -0.1752],
#           ...,
#           [-0.3348, -0.3171,  ..., -0.4766, -0.6007],
# ...
